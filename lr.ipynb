# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_excel("a.xlsx")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(df.area,df.price,color="red",marker="x")
plt.xlabel("area")
plt.ylabel("price")
plt.show()

# %%
reg = linear_model.LinearRegression()
reg.fit(df[["area"]],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
d= pd.read_excel("Book1.xlsx")
d
# Out:
#     area        prices
# 0   3212  6.167664e+05
# 1    342  2.270558e+05
# 2  32432  4.584482e+06
# 3  23423  3.361171e+06
# 4   4532  7.960062e+05
# 5   2345  4.990385e+05
# 6    234  2.123908e+05
# 7  32234  4.557596e+06
# 8    242  2.134771e+05

# %%
d["prices"]=a
d.to_excel("Book1.xlsx",index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 d["prices"]=a
#       2 d.to_excel("Book1.xlsx",index=False)
#
# NameError: name 'a' is not defined

# %%
d
# Out:
#     area        prices
# 0   3212  6.167664e+05
# 1    342  2.270558e+05
# 2  32432  4.584482e+06
# 3  23423  3.361171e+06
# 4   4532  7.960062e+05
# 5   2345  4.990385e+05
# 6    234  2.123908e+05
# 7  32234  4.557596e+06
# 8    242  2.134771e+05

# %%
plt.scatter(df.area,df.price,color="red",marker="x")
plt.xlabel("area")
plt.ylabel("price")
plt.plot(df.area,reg.predict(df[["area"]]))
plt.show()

# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd
