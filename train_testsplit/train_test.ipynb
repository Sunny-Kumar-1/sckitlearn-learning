# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("carprices.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Mileage        20 non-null     int64
#  1   Age(yrs)       20 non-null     int64
#  2   Sell Price($)  20 non-null     int64
# dtypes: int64(3)
# memory usage: 612.0 bytes

# %%
plt.scatter(df["Mileage"],df["Sell Price($)"])
plt.xlabel("price")
plt.ylabel("mileage")
# Out:
# Text(0, 0.5, 'mileage')

# %%
plt.scatter(df["Age(yrs)"],df["Sell Price($)"])

# %%
x=df[["Mileage","Age(yrs)"]]
y=df["Sell Price($)"]
x
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5
# 13    58780         4
# 14    82450         7
# 15    25400         3
# 16    28000         2
# 17    69000         5
# 18    87600         8
# 19    52000         5

# %%
from sklearn.model_selection import train_test_split

# %%
X_Train,X_Test,Y_Train,Y_Test = train_test_split(x,y,test_size=0.2)

# %%
X_Train
# Out:
#     Mileage  Age(yrs)
# 14    82450         7
# 2     57000         5
# 11    79000         7
# 3     22500         2
# 0     69000         6
# 12    59000         5
# 4     46000         4
# 6     52000         5
# 9     67000         6
# 16    28000         2
# 17    69000         5
# 18    87600         8
# 19    52000         5
# 5     59000         5
# 8     91000         8
# 7     72000         6

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_Train,Y_Train)
# Out:
# LinearRegression()

# %%
lr.predict(X_Test)
# Out:
# array([34967.38181927, 40324.46120866, 15618.55112715, 23556.59131218])

# %%
lr.score(X_Test,Y_Test)
# Out:
# 0.6788538007922742
